# %%
import pandas as pd 
import glob

# %%
list = [r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_cleveland.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_diabetes.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_ionosphere.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_sonar.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_wdbc.xlsx']

# %%
df_list = [pd.read_excel(file) for file in list]

# %%
combined_df = pd.concat(df_list, ignore_index=True)

# %%
combined_df = combined_df.iloc[:,:8]

# %%
combined_df
# Out:
#          Model  Type of dataset  Average Accuracy  Average AUC  \
# 0        L1SVM        Not noise          0.838280     0.838476
# 1        L1SVM            Noise          0.785591     0.784821
# 2        L1SVM          Outlier          0.785484     0.791390
# 3        L1SVM  Noise + Outlier          0.734946     0.738004
# 4        L2SVM        Not noise          0.838172     0.836778
# ..         ...              ...               ...          ...
# 135  FisherSVM  Noise + Outlier          0.847180     0.851997
# 136     RFESVM        Not noise          0.975345     0.972936
# 137     RFESVM            Noise          0.896335     0.886629
# 138     RFESVM          Outlier          0.917481     0.926638
# 139     RFESVM  Noise + Outlier          0.855984     0.860543
#
#      Average F1 Score  Average G-Mean  Average train_time  \
# 0            0.837574        0.833741            0.038930
# 1            0.784129        0.777550            0.025879
# ...

# %%
avg_df = combined_df.groupby(['Model', 'Type of dataset']).mean(numeric_only=True).reset_index()

# %%
avg_df
# Out:
#          Model  Type of dataset  Average Accuracy  Average AUC  \
# 0    FisherSVM            Noise          0.784862     0.781623
# 1    FisherSVM  Noise + Outlier          0.738799     0.739813
# 2    FisherSVM        Not noise          0.830158     0.828207
# 3    FisherSVM          Outlier          0.784505     0.784133
# 4        L1SVM            Noise          0.787632     0.785034
# 5        L1SVM  Noise + Outlier          0.733495     0.734718
# 6        L1SVM        Not noise          0.836435     0.832481
# 7        L1SVM          Outlier          0.786216     0.787766
# 8        L2SVM            Noise          0.789769     0.787886
# 9        L2SVM  Noise + Outlier          0.733827     0.735744
# 10       L2SVM        Not noise          0.835002     0.833342
# 11       L2SVM          Outlier          0.781434     0.785382
# 12       MILP1            Noise          0.792336     0.789372
# 13       MILP1  Noise + Outlier          0.739862     0.740456
# ...

# %%
avg_df.to_excel("average_metrics_per_model_dataset.xlsx", index=False)
