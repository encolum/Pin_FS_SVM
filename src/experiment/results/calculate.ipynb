# %%
import pandas as pd 
import glob

# %%
list = [r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_wdbc_2025-05-10_L1.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_sonar_2025-05-11_L1.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_ionosphere_2025-05-10_L1.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_diabetes_2025-05-10_L1.xlsx',
           r'D:\Pin_FS_SVM\src\experiment\results\experiment_results_cleveland_2025-05-10_L1.xlsx']

# %%
df_list = [pd.read_excel(file) for file in list]

# %%
combined_df = pd.concat(df_list, ignore_index=True)

# %%
combined_df = combined_df.iloc[:,:8]

# %%
combined_df
# Out:
#          Model    Type of model  Average Accuracy  Average AUC  \
# 0        L1SVM        Not noise          0.975345     0.972936
# 1        L1SVM            Noise          0.896335     0.886629
# 2        L1SVM          Outlier          0.917481     0.926638
# 3        L1SVM  Noise + Outlier          0.855984     0.860543
# 4        L2SVM        Not noise          0.977099     0.974287
# ..         ...              ...               ...          ...
# 135  FisherSVM  Noise + Outlier          0.728172     0.733210
# 136     RFESVM        Not noise          0.841505     0.841621
# 137     RFESVM            Noise          0.798925     0.797392
# 138     RFESVM          Outlier          0.788817     0.794168
# 139     RFESVM  Noise + Outlier          0.738172     0.741327
#
#      Average F1 Score  Average G-Mean  Average train_time  \
# 0            0.975295        0.972666            0.063472
# 1            0.896128        0.885088            0.066105
# ...

# %%
avg_df = combined_df.groupby(['Model', 'Type of model']).mean(numeric_only=True).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 avg_df = combined_df.groupby(['Model', 'Type of dataset']).mean(numeric_only=True).reset_index()
#
# File d:\Miniconda\envs\myenv\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %%
avg_df
# Out:
#          Model  Type of dataset  Average Accuracy  Average AUC  \
# 0    FisherSVM            Noise          0.794420     0.787500
# 1    FisherSVM  Noise + Outlier          0.740406     0.736105
# 2    FisherSVM        Not noise          0.833964     0.829879
# 3    FisherSVM          Outlier          0.780295     0.778421
# 4        L1SVM            Noise          0.791786     0.784492
# 5        L1SVM  Noise + Outlier          0.739899     0.737403
# 6        L1SVM        Not noise          0.834346     0.829166
# 7        L1SVM          Outlier          0.784124     0.781476
# 8        L2SVM            Noise          0.792434     0.785195
# 9        L2SVM  Noise + Outlier          0.735772     0.733571
# 10       L2SVM        Not noise          0.828880     0.823841
# 11       L2SVM          Outlier          0.778509     0.777790
# 12       MILP1            Noise          0.796569     0.789048
# 13       MILP1  Noise + Outlier          0.741578     0.738154
# ...

# %%
avg_df.to_excel("average_metrics_per_model_dataset_not_stratified.xlsx", index=False)
