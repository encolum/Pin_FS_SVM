# %%
import pandas as pd 
import glob 
import os
PATH = os.getcwd()  
while not os.path.basename(PATH).startswith('Optimal-Robust-Feature-Selection'):
    parent = os.path.dirname(PATH)
    if parent == PATH:  
        break
    PATH = parent
results_dir = os.path.join(PATH, 'src', 'experiment', 'results')
datasets = ['cleveland', 'diabetes', 'ionosphere', 'sonar', 'wdbc', 'colon']
list = [os.path.join(results_dir, f'experiment_results_{dataset}.xlsx') for dataset in datasets]

# %%
df_list = [pd.read_excel(file) for file in list]

# %%
combined_df = pd.concat(df_list, ignore_index=True)

# %%
combined_df = combined_df.iloc[:,:8]

# %%
combined_df
# Out:
#          Model  Type of dataset  Average Accuracy  Average AUC  \
# 0        L1SVM        Not noise          0.838280     0.838476
# 1        L1SVM            Noise          0.785591     0.784821
# 2        L1SVM          Outlier          0.785484     0.791390
# 3        L1SVM  Noise + Outlier          0.734946     0.738004
# 4        L2SVM        Not noise          0.838172     0.836778
# ..         ...              ...               ...          ...
# 163  FisherSVM  Noise + Outlier          0.758974     0.741389
# 164     RFESVM        Not noise          0.791026     0.782500
# 165     RFESVM            Noise          0.710256     0.711429
# 166     RFESVM          Outlier          0.692308     0.710833
# 167     RFESVM  Noise + Outlier          0.692308     0.710833
#
#      Average F1 Score  Average G-Mean  Average train_time  \
# 0            0.837574        0.833741            0.038930
# 1            0.784129        0.777550            0.025879
# 2            0.786142        0.785037            0.025614
# 3            0.737131        0.734668            0.025873
# 4            0.837311        0.831671            0.040423
# ..                ...             ...                 ...
# 163          0.758978        0.722948            4.715056
# 164          0.787402        0.766634          942.125757
# 165          0.710099        0.689102          844.958844
# 166          0.697893        0.687868          965.411293
# 167          0.697893        0.687868          564.078371
#
#      Average num_features
# 0                     8.5
# 1                    10.8
# 2                     9.6
# 3                    11.1
# 4                    13.0
# ..                    ...
# 163                   7.6
# 164                   4.8
# 165                   4.8
# 166                  10.2
# 167                   8.6
#
# [168 rows x 8 columns]

# %%
# Calculate mean and std, then format as 'mean ± std'
def mean_std_format(x):
    mean_val = x.mean()
    std_val = x.std()
    return f"{mean_val:.4f} ± {std_val:.4f}"

avg_df = combined_df.groupby(['Model', 'Type of dataset']).agg(
    lambda x: mean_std_format(x) if x.dtype in ['float64', 'int64'] else x.iloc[0]
).reset_index()

# %%
avg_df
# Out:
#          Model  Type of dataset  Average Accuracy  Average AUC  \
# 0    FisherSVM            Noise          0.775205     0.771545
# 1    FisherSVM  Noise + Outlier          0.742162     0.740075
# 2    FisherSVM        Not noise          0.828978     0.824756
# 3    FisherSVM          Outlier          0.780037     0.779324
# 4        L1SVM            Noise          0.774736     0.772766
# 5        L1SVM  Noise + Outlier          0.726630     0.730737
# 6        L1SVM        Not noise          0.828867     0.824151
# 7        L1SVM          Outlier          0.770564     0.774944
# 8        L2SVM            Noise          0.768183     0.769125
# 9        L2SVM  Noise + Outlier          0.727120     0.729277
# 10       L2SVM        Not noise          0.821903     0.821951
# 11       L2SVM          Outlier          0.764016     0.768791
# 12       MILP1            Noise          0.789767     0.784020
# 13       MILP1  Noise + Outlier          0.740484     0.738760
# 14       MILP1        Not noise          0.823125     0.820048
# 15       MILP1          Outlier          0.775260     0.780164
# 16    PinFSSVM            Noise          0.799475     0.794726
# 17    PinFSSVM  Noise + Outlier          0.754929     0.757793
# 18    PinFSSVM        Not noise          0.839867     0.834617
# 19    PinFSSVM          Outlier          0.788524     0.792699
# 20  PinballSVM            Noise          0.769871     0.772188
# 21  PinballSVM  Noise + Outlier          0.727132     0.731305
# 22  PinballSVM        Not noise          0.825596     0.823326
# 23  PinballSVM          Outlier          0.772725     0.778796
# 24      RFESVM            Noise          0.778876     0.776315
# 25      RFESVM  Noise + Outlier          0.727618     0.732701
# 26      RFESVM        Not noise          0.830752     0.827142
# 27      RFESVM          Outlier          0.773756     0.777701
#
#     Average F1 Score  Average G-Mean  Average train_time  Average num_features
# 0           0.773861        0.759858            1.099035              8.250000
# 1           0.742412        0.728836            1.182800              8.716667
# 2           0.827863        0.816849            1.011146              8.800000
# 3           0.779996        0.767191            1.058154              7.650000
# 4           0.774734        0.762686            0.108398             11.500000
# 5           0.727498        0.718218            0.110438             11.483333
# 6           0.828242        0.817249            0.111892              9.266667
# 7           0.771778        0.763219            0.106070             10.083333
# 8           0.768116        0.757833            0.108626            357.500000
# 9           0.728377        0.717605            0.115885            357.500000
# 10          0.822160        0.815483            0.108833            357.500000
# 11          0.765745        0.757703            0.102614            357.500000
# 12          0.788784        0.774422            0.391485              9.150000
# 13          0.741732        0.728865            0.616819              7.116667
# 14          0.822877        0.813044            0.468361              7.333333
# 15          0.777254        0.770916            0.480287              7.983333
# 16          0.798997        0.786381            0.997883              7.116667
# 17          0.755609        0.746875            0.492600              6.500000
# 18          0.838773        0.827119            0.549937              6.633333
# 19          0.790208        0.783921            0.401979              5.750000
# 20          0.769782        0.761172            0.272727            357.500000
# 21          0.727431        0.717301            0.292368            357.500000
# 22          0.825664        0.816952            0.343683            357.500000
# 23          0.774647        0.767868            0.351856            357.500000
# 24          0.778625        0.766239          141.417074              9.666667
# 25          0.729417        0.722005           94.627076              9.900000
# 26          0.830322        0.820655          157.638158              7.833333
# 27          0.774770        0.765893          161.530727              8.500000

# %%
avg_df.to_excel("average_metrics_per_model_dataset.xlsx", index=False)
